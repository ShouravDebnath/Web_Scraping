# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
import time

# Start browser
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))

# Open sitemap
driver.get("https://www.geneon.net/sitemap.xml")

time.sleep(5)

# Get page source
html = driver.page_source

# Parse XML
soup = BeautifulSoup(html, "xml")

# Extract URLs
urls = [loc.text for loc in soup.find_all("loc")]

print("Total URLs:", len(urls))
print(urls[:10])
# Out:
# Total URLs: 443
# ['https://www.geneon.net/', 'https://www.geneon.net/english-pages/ablage/', 'https://www.geneon.net/products/dna-rna-extraction-1/', 'https://www.geneon.net/products/dna-rna-extraction-1/gelantin-purification/', 'https://www.geneon.net/products/dna-rna-extraction-1/fungus-dna-extraction-kit/', 'https://www.geneon.net/products/dna-rna-extraction-1/bacterial-dna-isolation/', 'https://www.geneon.net/products/dna-rna-extraction-1/tissue-dna-purification/', 'https://www.geneon.net/products/dna-rna-extraction-1/tissue-viral-nucleic-acid-purification/', 'https://www.geneon.net/blood-tissue-combi-dna-extraction-kit/', 'https://www.geneon.net/products/dna-rna-extraction-1/plant-dna-purification/']

# %%
import random
import os
folder = "HTML-geneon_pages"

def save_page(driver, url, filename, retries=3):

    for attempt in range(retries):

        try:
            driver.get(url)

            time.sleep(random.uniform(3,6))  # human-like delay

            html = driver.page_source

            with open(os.path.join(folder, filename), "w", encoding="utf-8") as f:
                f.write(html)

            return True

        except Exception as e:
            print("Error:", e)

    return False
# 
for i, url in enumerate(urls):

    ok = save_page(driver, url, f"page_{i}.html")

    if ok:
        print("Saved:", i)
    else:
        print("Skipped:", i)

# 
driver.quit()
# Out:
# Saved: 0
# Saved: 1
# Saved: 2
# Saved: 3
# Saved: 4
# Saved: 5
# Saved: 6
# Saved: 7
# Saved: 8
# Saved: 9
# Saved: 10
# Saved: 11
# Saved: 12
# Saved: 13
# Saved: 14
# Saved: 15
# Saved: 16
# Saved: 17
# Saved: 18
# Saved: 19
# Saved: 20
# Saved: 21
# Saved: 22
# Saved: 23
# Saved: 24
# Saved: 25
# Saved: 26
# Saved: 27
# Saved: 28
# Saved: 29
# Saved: 30
# Saved: 31
# Saved: 32
# Saved: 33
# Saved: 34
# Saved: 35
# Saved: 36
# Saved: 37
# Saved: 38
# Saved: 39
# Saved: 40
# Saved: 41
# Saved: 42
# Saved: 43
# Saved: 44
# Saved: 45
# Saved: 46
# Saved: 47
# Saved: 48
# Saved: 49
# Saved: 50
# Saved: 51
# Saved: 52
# Saved: 53
# Saved: 54
# Saved: 55
# Saved: 56
# Saved: 57
# Saved: 58
# Saved: 59
# Saved: 60
# Saved: 61
# Saved: 62
# Saved: 63
# Saved: 64
# Saved: 65
# Saved: 66
# Saved: 67
# Saved: 68
# Saved: 69
# Saved: 70
# Saved: 71
# Saved: 72
# Saved: 73
# Saved: 74
# Saved: 75
# Saved: 76
# Saved: 77
# Saved: 78
# Saved: 79
# Saved: 80
# Saved: 81
# Saved: 82
# Saved: 83
# Saved: 84
